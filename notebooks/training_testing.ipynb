# %%
import pandas as pd
from pyspark.sql.functions import (col, rand, udf, collect_set, collect_list, concat, array_distinct, flatten, when, length)
import pyspark.sql.functions as F
from pyspark.sql.types import ArrayType, StringType, FloatType
from unidecode import unidecode
import re
from functools import reduce
import numpy as np
import tensorflow as tf
import keras
from fuzzywuzzy import fuzz

from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU, Bidirectional, GlobalMaxPooling1D, Layer, Masking, Lambda, Permute
import os
import pickle
from keras.layers import Bidirectional
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import functools
from keras.callbacks import ModelCheckpoint
from keras.layers import Dropout, concatenate
from keras.activations import relu
from sklearn.model_selection import train_test_split

def custom_standardization(input_data):
    lowercase     = tf.strings.lower(input_data)
    stripped_html = tf.strings.regex_replace(lowercase, "<br />", " ")
    stripped_punc = tf.strings.regex_replace(stripped_html, 
                             "[%s]" % re.escape(string.punctuation), "")
    return stripped_punc
    
def char_split(input_data):
  return tf.strings.unicode_split(input_data, 'UTF-8')


def get_conv_pool(x_input, max_len, suffix, n_grams=[2,3,5,8, 13], feature_maps=128):
    branches = []
    for n in n_grams:
        branch = tf.keras.layers.Conv1D(filters=feature_maps, kernel_size=n, activation=relu,
                        name='Conv_' + suffix + '_' + str(n))(x_input)
        branch = tf.keras.layers.MaxPooling1D(pool_size=max_len - n + 1,
                                              strides=1, padding='valid',
                              name='MaxPooling_' + suffix + '_' + str(n))(branch)
        branch = tf.keras.layers.Flatten(name='Flatten_' + suffix + '_' + str(n))(branch)
        branches.append(branch)
    return branches

class poiNames_C2V:
    
    def __init__(self, embedding_dim:int, char_to_index:dict):

        self.char_to_index = char_to_index
        self.index_to_char = {char_to_index[char]: char for char in char_to_index}
        self.input_size = MAX_NAME_LEN
        self.embedding_dim = embedding_dim
        self.vocabulary_size = len(char_to_index)

        input_sequence = tf.keras.layers.Input(shape=self.input_size, name='input_sequence')
        # x = tf.keras.layers.Masking(mask_value=0)(input_sequence)
        x = tf.keras.layers.Embedding(input_dim=self.input_size, output_dim=self.embedding_dim, mask_zero=True)(input_sequence)
        self.embedding_layer = tf.keras.models.Model(inputs=[input_sequence], outputs=x)

        sequences_emb = self.embedding_layer(input_sequence)
        branches = get_conv_pool(sequences_emb, max_len=100, suffix='unique')
        z = concatenate(branches, axis=-1)
        self.convolutions_layer = tf.keras.models.Model(inputs=[input_sequence], outputs=z)

        left_branch_input = tf.keras.layers.Input(shape=(self.input_size, 1), name='left_branch_input')
        right_branch_input = tf.keras.layers.Input(shape=(self.input_size, 1),name='right_branch_input')

        left_branch_features = self.convolutions_layer(left_branch_input)
        right_branch_features = self.convolutions_layer(right_branch_input)

        
        
        product_layer = tf.keras.layers.Multiply()([left_branch_features, right_branch_features])
        difference_layer = tf.keras.layers.Subtract()([left_branch_features, right_branch_features])
        concat_layer = tf.keras.layers.Concatenate(axis=1)([left_branch_features, right_branch_features])
        
        representation_layer = tf.keras.layers.Concatenate(axis=1)([
                                                                    concat_layer, product_layer, difference_layer, 
                                                                    ])
        x = tf.keras.layers.Dense(1024, activation='relu')(representation_layer)
        x = tf.keras.layers.Dropout(0.4)(x)
        x = tf.keras.layers.Dense(1024, activation='relu')(x)
        x = tf.keras.layers.Dropout(0.4)(x)
        x = tf.keras.layers.Dense(1024, activation='relu')(x)
        model_output = tf.keras.layers.Dense(1, activation='sigmoid')(x)
        
        self.model = tf.keras.models.Model(inputs=[left_branch_input, right_branch_input], outputs=model_output)
        self.model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy',
                                                              tf.keras.metrics.Precision(),
                                                              tf.keras.metrics.Recall()])
        
    def fit(
        self, name_pairs, target, max_epochs:int, patience:int, validation_split:float, batch_size:int, callbacks: iter):
        
        X1 = encode_sparsed_list(name_pairs[:, 0],char_to_index_dict=self.char_to_index, max_len=MAX_NAME_LEN)
        X2 = encode_sparsed_list(name_pairs[:, 1], char_to_index_dict=self.char_to_index, max_len=MAX_NAME_LEN)
        X1 = np.expand_dims(X1, axis=-1)
        X2 = np.expand_dims(X2, axis=-1)
        X1_pad = tf.keras.preprocessing.sequence.pad_sequences(X1)
        X2_pad = tf.keras.preprocessing.sequence.pad_sequences(X2)
        
        self.model.fit((X1_pad, X2_pad), target,verbose=1,
                    batch_size=batch_size, epochs=max_epochs,
                    validation_split=validation_split,
                    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience)]
                            + callbacks)


    def save_model(self, path_to_model):
        '''
        Saves trained model to directory.
    
        :param path_to_model: str, path to save model.
        '''
    
        if not os.path.exists(path_to_model):
            os.makedirs(path_to_model)
        
        self.model.save_weights(path_to_model + '/weights.h5')
    
        with open(path_to_model + '/model.pkl', 'wb') as f:
            pickle.dump([self.embedding_dim, self.char_to_index], f, protocol=2)


    def load_model(self, path):
        '''
        Loads trained model.
    
        :param path: loads model from `path`.
    
        :return c2v_model: Chars2Vec object, trained model.
        '''
        path_to_model = path
    
        with open(path_to_model + '/model.pkl', 'rb') as f:
            structure = pickle.load(f)
            embedding_dim, char_to_index = structure[0], structure[1]
    
        model = poiNames_C2V(embedding_dim=embedding_dim, char_to_index=char_to_index)
        model.model.load_weights(path_to_model + '/weights.h5')
        model.model.compile(optimizer='adam', loss='mae')
    
        return model


    def vectorize(self, iterable: iter) -> np.array:
        
        X = encode_sparsed_list(iterable,char_to_index_dict=self.char_to_index)
        X = np.expand_dims(X, axis=-1)
        X_pad = tf.keras.preprocessing.sequence.pad_sequences(X)

        return X_pad

# %%
MAX_NAME_LEN = 100
char_to_index = catalog.load('vocabulary_file')
# Out:
# [09/03/23 21:13:36] INFO     Loading data from 'vocabulary_file' (JSONDataSet)...               ]8;id=123499;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=993807;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py#475\475]8;;\

# %%
poi_c2v = poiNames_C2V(150, char_to_index)
# Out:
# 2023-09-03 21:13:36.723372: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
X_train = catalog.load('df_training_data')
X_train[X_train['target'] == 0]
# Out:
#                     INFO     Loading data from 'df_training_data' (CSVDataSet)...               ]8;id=892652;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=484033;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py#475\475]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        reference_id     brand  \
# 29824   47905637612       NaN
# 29825   33939964186       NaN
# 29826   33920295151       NaN
# 29827    9151154135       NaN
# 29828   34029676494  Domino's
# ...             ...       ...
# 59643   33933382525       NaN
# 59644   33950966775       NaN
# 59645   34005477933       NaN
# 59646    2904773690       NaN
# 59647   33937469763       NaN
#
#                                                     name  \
# 29824                                        Olabarrieta
# 29825                                         Hotel Selu
# 29826  Centro Privado de Educación Infantil Jugar Y S...
# 29827                                      Mi Peluquería
# 29828                                           Domino's
# ...                                                  ...
# 59643                                             Llesca
# 59644  Centro Privado Autorizado de Enseñanzas Deport...
# 59645                        Restaurante Rincon De Pedro
# 59646                                    Font de l'Aueta
# 59647                                        Led Serveis
#
#                              alt_name  \
# 29824                     Casa Pancho
# 29825                         Miranda
# 29826  Enrique Tomás Jamon-Tapas-Vino
# 29827                          Hawaii
# 29828                     Pizza Tutto
# ...                               ...
# 59643             Pico Las Rebequeras
# 59644     Restaurante Bodegon Del Mar
# 59645     Apartamento Gran Via Callao
# 59646                            Moka
# 59647                Braseria Nicasio
#
#                                                     tags   latitude  \
# 29824  "license"=>"ODbL", "osm_uid"=>"1", "alt_name"=...  43.273544
# 29825  "fax"=>"+(34)-(957)-478376", "user"=>"tomtom",...  37.884247
# 29826  "user"=>"tomtom", "phone"=>"+34600257838", "li...  40.588801
# 29827  "phone"=>"+34 942 31 25 75", "license"=>"ODbL"...  43.469193
# 29828  "user"=>"tomtom", "phone"=>"+34910900924", "cu...  40.402120
# ...                                                  ...        ...
# 59643  "user"=>"tomtom", "phone"=>"+34925541064", "cu...  40.121636
# 59644  "user"=>"tomtom", "phone"=>"+34912115601", "sc...  40.373642
# 59645  "user"=>"tomtom", "email"=>"rincondepedro@live...  38.077685
# 59646  "license"=>"ODbL", "osm_uid"=>"1", "alt_name"=...  38.736821
# 59647  "user"=>"tomtom", "craft"=>"electronics_repair...  42.115739
#
#        longitude               category_fields  \
# 29824  -3.045194            ['place=locality']
# 29825  -4.783952             ['tourism=hotel']
# 29826  -3.708725      ['amenity=kindergarten']
# 29827  -3.808571          ['shop=hairdresser']
# 29828  -3.678620        ['amenity=restaurant']
# ...          ...                           ...
# 59643  -3.849563        ['amenity=restaurant']
# 59644  -3.920745            ['amenity=school']
# 59645  -0.649647        ['amenity=restaurant']
# 59646  -0.353900            ['natural=spring']
# 59647   2.762596  ['craft=electronics_repair']
#
#                                          name_normalized  \
# 29824                                        olabarrieta
# 29825                                         hotel selu
# 29826  centro privado de educacion infantil jugar y s...
# 29827                                      mi peluqueria
# 29828                                            dominos
# ...                                                  ...
# 59643                                             llesca
# 59644  centro privado autorizado de ensenanzas deport...
# 59645                        restaurante rincon de pedro
# 59646                                     font de laueta
# 59647                                        led serveis
#
#                   alt_name_normalized              run_id country  target
# 29824                     casa pancho  20230901-test-0006     esp       0
# 29825                         miranda  20230901-test-0006     esp       0
# 29826  enrique tomas jamon tapas vino  20230901-test-0006     esp       0
# 29827                          hawaii  20230901-test-0006     esp       0
# 29828                     pizza tutto  20230901-test-0006     esp       0
# ...                               ...                 ...     ...     ...
# 59643             pico las rebequeras  20230901-test-0006     esp       0
# 59644     restaurante bodegon del mar  20230901-test-0006     esp       0
# 59645     apartamento gran via callao  20230901-test-0006     esp       0
# 59646                            moka  20230901-test-0006     esp       0
# 59647                braseria nicasio  20230901-test-0006     esp       0
#
# [29824 rows x 13 columns]

# %%
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        reference_id     brand  \
# 29824   47905637612       NaN
# 29825   33939964186       NaN
# 29826   33920295151       NaN
# 29827    9151154135       NaN
# 29828   34029676494  Domino's
# ...             ...       ...
# 59643   33933382525       NaN
# 59644   33950966775       NaN
# 59645   34005477933       NaN
# 59646    2904773690       NaN
# 59647   33937469763       NaN
#
#                                                     name  \
# 29824                                        Olabarrieta
# 29825                                         Hotel Selu
# 29826  Centro Privado de Educación Infantil Jugar Y S...
# 29827                                      Mi Peluquería
# 29828                                           Domino's
# ...                                                  ...
# 59643                                             Llesca
# 59644  Centro Privado Autorizado de Enseñanzas Deport...
# 59645                        Restaurante Rincon De Pedro
# 59646                                    Font de l'Aueta
# 59647                                        Led Serveis
#
#                                       alt_name  \
# 29824                            Las Barrietas
# 29825               Sercotel Hotels Selu Hotel
# 29826                           Jugar Y Sentir
# 29827                   Peluquería Nuria Bailo
# 29828                          Domino's Tellez
# ...                                        ...
# 59643                   Gastrotaberna Illescas
# 59644  Ufedema-Centro de Enseñanzas deportivas
# 59645                          Rincon De Pedro
# 59646                         la Font de Cossi
# 59647                     Led Serveis Banyoles
#
#                                                     tags   latitude  \
# 29824  "license"=>"ODbL", "osm_uid"=>"1", "alt_name"=...  43.273544
# 29825  "fax"=>"+(34)-(957)-478376", "user"=>"tomtom",...  37.884247
# 29826  "user"=>"tomtom", "phone"=>"+34600257838", "li...  40.588801
# 29827  "phone"=>"+34 942 31 25 75", "license"=>"ODbL"...  43.469193
# 29828  "user"=>"tomtom", "phone"=>"+34910900924", "cu...  40.402120
# ...                                                  ...        ...
# 59643  "user"=>"tomtom", "phone"=>"+34925541064", "cu...  40.121636
# 59644  "user"=>"tomtom", "phone"=>"+34912115601", "sc...  40.373642
# 59645  "user"=>"tomtom", "email"=>"rincondepedro@live...  38.077685
# 59646  "license"=>"ODbL", "osm_uid"=>"1", "alt_name"=...  38.736821
# 59647  "user"=>"tomtom", "craft"=>"electronics_repair...  42.115739
#
#        longitude               category_fields  \
# 29824  -3.045194            ['place=locality']
# 29825  -4.783952             ['tourism=hotel']
# 29826  -3.708725      ['amenity=kindergarten']
# 29827  -3.808571          ['shop=hairdresser']
# 29828  -3.678620        ['amenity=restaurant']
# ...          ...                           ...
# 59643  -3.849563        ['amenity=restaurant']
# 59644  -3.920745            ['amenity=school']
# 59645  -0.649647        ['amenity=restaurant']
# 59646  -0.353900            ['natural=spring']
# 59647   2.762596  ['craft=electronics_repair']
#
#                                          name_normalized  \
# 29824                                        olabarrieta
# 29825                                         hotel selu
# 29826  centro privado de educacion infantil jugar y s...
# 29827                                      mi peluqueria
# 29828                                            dominos
# ...                                                  ...
# 59643                                             llesca
# 59644  centro privado autorizado de ensenanzas deport...
# 59645                        restaurante rincon de pedro
# 59646                                     font de laueta
# 59647                                        led serveis
#
#                            alt_name_normalized              run_id country  \
# 29824                            las barrietas  20230901-test-0006     esp
# 29825               sercotel hotels selu hotel  20230901-test-0006     esp
# 29826                           jugar y sentir  20230901-test-0006     esp
# 29827                   peluqueria nuria bailo  20230901-test-0006     esp
# 29828                           dominos tellez  20230901-test-0006     esp
# ...                                        ...                 ...     ...
# 59643                   gastrotaberna illescas  20230901-test-0006     esp
# 59644  ufedema centro de ensenanzas deportivas  20230901-test-0006     esp
# 59645                          rincon de pedro  20230901-test-0006     esp
# 59646                         la font de cossi  20230901-test-0006     esp
# 59647                     led serveis banyoles  20230901-test-0006     esp
#
#        target
# 29824       0
# 29825       0
# 29826       0
# 29827       0
# 29828       0
# ...       ...
# 59643       0
# 59644       0
# 59645       0
# 59646       0
# 59647       0
#
# [29824 rows x 13 columns]

# %%
catalog.load('df_negative_pairs').show()
# Out:
# [09/03/23 21:20:20] INFO     Loading data from 'df_negative_pairs' (SparkDataSet)...            ]8;id=597276;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=767231;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py#475\475]8;;\
# +------------+--------+--------------------+--------------------+--------------------+----------+----------+--------------------+--------------------+--------------------+------------------+-------+
# |reference_id|   brand|                name|            alt_name|                tags|  latitude| longitude|     category_fields|     name_normalized| alt_name_normalized|            run_id|country|
# +------------+--------+--------------------+--------------------+--------------------+----------+----------+--------------------+--------------------+--------------------+------------------+-------+
# | 46320957956|    null|Cámaras de tráfic...|Escultor Viciano;...|"license"=>"ODbL"...|39.9844658|-0.0389732|[man_made=surveil...|camaras de trafic...|escultor viciano ...|20230901-test-0005|    esp|
# | 33890660161|    null|       Bar El Carmen|           El Carmen|"user"=>"tomtom",...| 39.406133| -2.424481|[amenity=restaurant]|       bar el carmen|           el carmen|20230901-test-0005|    esp|
# | 34029728012|Domino's|Domino's Castelld...|            Domino's|"user"=>"tomtom",...|  41.27693|   1.97624|[amenity=restaurant]|dominos castellde...|             dominos|20230901-test-0005|    esp|
# | 34019568206|    null|Centro Privado Fo...|            Forhermo|"user"=>"tomtom",...| 42.865795| -8.554934|    [amenity=school]|centro privado fo...|            forhermo|20230901-test-0005|    esp|
# | 33953263974|    null|Pizzeria Restaura...|         Casa Blanca|"user"=>"tomtom",...| 28.651726|-17.759724|[amenity=restaurant]|pizzeria restaura...|         casa blanca|20230901-test-0005|    esp|
# | 33942373318|    null|Restaurante La Tabla|            La Tabla|"user"=>"tomtom",...| 42.941396| -3.599076|[amenity=restaurant]|restaurante la tabla|            la tabla|20230901-test-0005|    esp|
# | 33988956498|    null|     Asesoría Mabesu|              Mabesu|"user"=>"tomtom",...|39.5749354|-0.5217668|    [office=company]|     asesoria mabesu|              mabesu|20230901-test-0005|    esp|
# | 10373751617|    null|Iglesia de Nuestr...|Antiguo Hospital ...|"license"=>"ODbL"...|37.3900325|-5.9934598|[amenity=place_of...|iglesia de nuestr...|antiguo hospital ...|20230901-test-0005|    esp|
# | 34016790309|    null|        Paso Honroso|Restaurante Paso ...|"user"=>"tomtom",...| 42.582253| -5.573196|[amenity=restaurant]|        paso honroso|restaurante paso ...|20230901-test-0005|    esp|
# | 33988562256| CajaSur|       CajaSur Banco|             CajaSur|"user"=>"tomtom",...|   37.7582|  -4.94445|       [amenity=atm]|       cajasur banco|             cajasur|20230901-test-0005|    esp|
# | 33957509360|    null|Restaurante Los M...|           Los Maños|"user"=>"tomtom",...|  41.55371|   2.03179|[amenity=restaurant]|restaurante los m...|           los manos|20230901-test-0005|    esp|
# | 33956990499|    null|Cafeteria El Cort...|     El Corte Inglés|"user"=>"tomtom",...| 28.095597|-15.456521|[amenity=restaurant]|cafeteria el cort...|     el corte ingles|20230901-test-0005|    esp|
# | 33989824930|    null|Apartamentos Maracay|             Maracay|"user"=>"tomtom",...|  36.74276|  -2.61394| [tourism=apartment]|apartamentos maracay|             maracay|20230901-test-0005|    esp|
# | 33975605463|    null|Juzgado de lo Con...|             Juzgado|"fax"=>"+(34)-(95...| 36.511803|-6.2798977|[amenity=courthouse]|juzgado de lo con...|             juzgado|20230901-test-0005|    esp|
# | 33913974848|    null|   Recambios Serrano|Recambios Serrano...|"user"=>"tomtom",...|36.6751827|-4.5445184|    [shop=car_parts]|   recambios serrano|recambios serrano...|20230901-test-0005|    esp|
# | 33935495691|    null|Zentral Club Apar...|        Zentral Club|"user"=>"tomtom",...| 43.317547| -6.220337| [tourism=apartment]|zentral club apar...|        zentral club|20230901-test-0005|    esp|
# | 47171167225|    null|Real Colegio Univ...|  RCU María Cristina|"license"=>"ODbL"...|40.5884687|-4.1506488|      [barrier=gate]|real colegio univ...|  rcu maria cristina|20230901-test-0005|    esp|
# | 43649688828|    null|  ZEC Xubia - Castro|  ZEC Xuvia - Castro|"license"=>"ODbL"...|43.4748792|-8.0026991|[leisure=nature_r...|    zec xubia castro|    zec xuvia castro|20230901-test-0005|    esp|
# |  7578721137|    null|C.S. Los Corrales...|Centro de Salud B...|"phone"=>"+34 942...|43.2550155|-4.0660586|    [amenity=clinic]|c s los corrales ...|centro de salud b...|20230901-test-0005|    esp|
# | 33932050953|    null|Centro Comercial ...|Centro Comercial ...|"user"=>"tomtom",...|38.2583189|-0.7138753|         [shop=mall]|centro comercial ...|centro comercial ...|20230901-test-0005|    esp|
# +------------+--------+--------------------+--------------------+--------------------+----------+----------+--------------------+--------------------+--------------------+------------------+-------+
# only showing top 20 rows

# %%
X_val = catalog.load('validation')
# Out:
# [09/03/23 20:47:29] INFO     Loading data from 'validation' (CSVDataSet)...                     ]8;id=809163;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=689885;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py#475\475]8;;\

# %%
catalog.list()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'df_normalized_pairs',
#     'df_negative_pairs',
#     'query_schema',
#     'df_schema',
#     'spatial_query',
#     'df_response',
#     'df_raw_names_sample',
#     'vocabulary_file',
#     'train',
#     'test',
#     'validation',
#     'tensorflow_model',
#     'training_history_loss',
#     'confussion_matrix_model',
#     'confussion_matrix_validation',
#     'classification_logs',
#     'parameters',
#     'params:run_id',
#     'params:country',
#     'params:provider',
#     'params:sample_round',
#     'params:query_parameters',
#     'params:query_parameters.om',
#     'params:query_parameters.om.schema_query',
#     'params:query_parameters.om.data_query',
#     'params:query_parameters.tt',
#     'params:query_parameters.tt.schema_query',
#     'params:query_parameters.tt.data_query',
#     'params:query_parameters.osm',
#     'params:query_parameters.osm.schema_query',
#     'params:query_parameters.osm.data_query',
#     'params:has_custom_credentials',
#     'params:custom_credentials',
#     'params:custom_credentials.host',
#     'params:custom_credentials.port',
#     'params:custom_credentials.database',
#     'params:custom_credentials.user',
#     'params:custom_credentials.password',
#     'params:col_om',
#     'params:che_om',
#     'params:kwt_om',
#     'params:mkd_om',
#     'params:glp_om',
#     'params:nld_om',
#     'params:rou_om',
#     'params:fin_om',
#     'params:rus_om',
#     'params:can_om',
#     'params:chl_om',
#     'params:ind_om',
#     'params:sau_om',
#     'params:per_om',
#     'params:gbr_om',
#     'params:esp_om',
#     'params:hkg_om',
#     'params:nor_om',
#     'params:lva_om',
#     'params:srb_om',
#     'params:omn_om',
#     'params:pol_om',
#     'params:mne_om',
#     'params:sgp_om',
#     'params:hrv_om',
#     'params:qat_om',
#     'params:ukr_om',
#     'params:isr_om',
#     'params:aus_om',
#     'params:swe_om',
#     'params:idn_om',
#     'params:prt_om',
#     'params:dza_om',
#     'params:isl_om',
#     'params:cyp_om',
#     'params:svk_om',
#     'params:dnk_om',
#     'params:vnm_om',
#     'params:deu_om',
#     'params:cze_om',
#     'params:hun_om',
#     'params:arg_om',
#     'params:fra_om',
#     'params:grc_om',
#     'params:mar_om',
#     'params:twn_om',
#     'params:irl_om',
#     'params:bra_om',
#     'params:egy_om',
#     'params:tur_om',
#     'params:svn_om',
#     'params:are_om',
#     'params:ken_om',
#     'params:zaf_om',
#     'params:tha_om',
#     'params:nzl_om',
#     'params:mys_om',
#     'params:ury_om',
#     'params:blr_om',
#     'params:bgr_om',
#     'params:bel_om',
#     'params:alb_om',
#     'params:ita_om',
#     'params:aut_om',
#     'params:usa_om',
#     'params:kor_om',
#     'params:ltu_om',
#     'params:est_om',
#     'params:mex_om',
#     'params:bih_om',
#     'params:kaz_om',
#     'params:phl_om',
#     'params:mlt_om',
#     'params:lux_om',
#     'params:jpn_om',
#     'params:col_osm',
#     'params:che_osm',
#     'params:kwt_osm',
#     'params:mkd_osm',
#     'params:glp_osm',
#     'params:nld_osm',
#     'params:rou_osm',
#     'params:fin_osm',
#     'params:rus_osm',
#     'params:can_osm',
#     'params:chl_osm',
#     'params:ind_osm',
#     'params:sau_osm',
#     'params:per_osm',
#     'params:gbr_osm',
#     'params:esp_osm',
#     'params:hkg_osm',
#     'params:nor_osm',
#     'params:lva_osm',
#     'params:srb_osm',
#     'params:omn_osm',
#     'params:pol_osm',
#     'params:mne_osm',
#     'params:sgp_osm',
#     'params:hrv_osm',
#     'params:qat_osm',
#     'params:ukr_osm',
#     'params:isr_osm',
#     'params:aus_osm',
#     'params:swe_osm',
#     'params:idn_osm',
#     'params:prt_osm',
#     'params:dza_osm',
#     'params:isl_osm',
#     'params:cyp_osm',
#     'params:svk_osm',
#     'params:dnk_osm',
#     'params:vnm_osm',
#     'params:deu_osm',
#     'params:cze_osm',
#     'params:hun_osm',
#     'params:arg_osm',
#     'params:fra_osm',
#     'params:grc_osm',
#     'params:mar_osm',
#     'params:twn_osm',
#     'params:irl_osm',
#     'params:bra_osm',
#     'params:egy_osm',
#     'params:tur_osm',
#     'params:svn_osm',
#     'params:are_osm',
#     'params:ken_osm',
#     'params:zaf_osm',
#     'params:tha_osm',
#     'params:nzl_osm',
#     'params:mys_osm',
#     'params:ury_osm',
#     'params:blr_osm',
#     'params:bgr_osm',
#     'params:bel_osm',
#     'params:alb_osm',
#     'params:ita_osm',
#     'params:aut_osm',
#     'params:usa_osm',
#     'params:kor_osm',
#     'params:ltu_osm',
#     'params:est_osm',
#     'params:mex_osm',
#     'params:bih_osm',
#     'params:kaz_osm',
#     'params:phl_osm',
#     'params:mlt_osm',
#     'params:lux_osm',
#     'params:jpn_osm',
#     'params:col_tt',
#     'params:che_tt',
#     'params:kwt_tt',
#     'params:mkd_tt',
#     'params:glp_tt',
#     'params:nld_tt',
#     'params:rou_tt',
#     'params:fin_tt',
#     'params:rus_tt',
#     'params:can_tt',
#     'params:chl_tt',
#     'params:ind_tt',
#     'params:sau_tt',
#     'params:per_tt',
#     'params:gbr_tt',
#     'params:esp_tt',
#     'params:hkg_tt',
#     'params:nor_tt',
#     'params:lva_tt',
#     'params:srb_tt',
#     'params:omn_tt',
#     'params:pol_tt',
#     'params:mne_tt',
#     'params:sgp_tt',
#     'params:hrv_tt',
#     'params:qat_tt',
#     'params:ukr_tt',
#     'params:isr_tt',
#     'params:aus_tt',
#     'params:swe_tt',
#     'params:idn_tt',
#     'params:prt_tt',
#     'params:dza_tt',
#     'params:isl_tt',
#     'params:cyp_tt',
#     'params:svk_tt',
#     'params:dnk_tt',
#     'params:vnm_tt',
#     'params:deu_tt',
#     'params:cze_tt',
#     'params:hun_tt',
#     'params:arg_tt',
#     'params:fra_tt',
#     'params:grc_tt',
#     'params:mar_tt',
#     'params:twn_tt',
#     'params:irl_tt',
#     'params:bra_tt',
#     'params:egy_tt',
#     'params:tur_tt',
#     'params:svn_tt',
#     'params:are_tt',
#     'params:ken_tt',
#     'params:zaf_tt',
#     'params:tha_tt',
#     'params:nzl_tt',
#     'params:mys_tt',
#     'params:ury_tt',
#     'params:blr_tt',
#     'params:bgr_tt',
#     'params:bel_tt',
#     'params:alb_tt',
#     'params:ita_tt',
#     'params:aut_tt',
#     'params:usa_tt',
#     'params:kor_tt',
#     'params:ltu_tt',
#     'params:est_tt',
#     'params:mex_tt',
#     'params:bih_tt',
#     'params:kaz_tt',
#     'params:phl_tt',
#     'params:mlt_tt',
#     'params:lux_tt',
#     'params:jpn_tt',
#     'params:om_data_query',
#     'params:om_schema_query',
#     'params:pois_number',
#     'params:model_parameters',
#     'params:model_parameters.init',
#     'params:model_parameters.init.embeding_size',
#     'params:model_parameters.init.input_size',
#     'params:model_parameters.fit',
#     'params:model_parameters.fit.max_epochs',
#     'params:model_parameters.fit.patience',
#     'params:model_parameters.fit.batch_size',
#     'params:model_parameters.prediction',
#     'params:model_parameters.prediction.threshold',
#     'params:split_params',
#     'params:split_params.test_size',
#     'params:split_params.stratification_columns',
#     'params:split_params.validation_size'
# ]

# %%
char_to_index = catalog.load('vocabulary_file')
# Out:
# [09/03/23 20:50:11] INFO     Loading data from 'vocabulary_file' (JSONDataSet)...               ]8;id=941861;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=979594;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py#475\475]8;;\

# %%
X1_train = X_train['name_normalized'].values
X2_train = X_train['alt_name_normalized'].values
target_train = X_train['target'].values

# %%
X1_val = X_val['name_normalized'].values
X2_val = X_val['alt_name_normalized'].values
target_val = X_val['target'].values

# %%
init_parameters = catalog.load('params:model_parameters.init')

model = char2vecCNN(
    input_size=init_parameters['input_size'],
    embedding_dim = init_parameters['input_size'],
    char_to_index = char_to_index)

fit_parameters = catalog.load('params:model_parameters.fit')
history = History()

model.fit(
    training_pairs=(X1_train, X2_train),
    target=target_train,
    max_epochs=fit_parameters['max_epochs'],
    patience=fit_parameters['patience'],
    validation_pairs=((X1_val, X2_val), (target_val)),
    batch_size=fit_parameters['batch_size'],
    callbacks=[history]
)
# Out:
# [09/03/23 20:50:35] INFO     Loading data from 'params:model_parameters.init'                   ]8;id=604040;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=125416;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py#475\475]8;;\
#                              (MemoryDataset)...
#                     INFO     Loading data from 'params:model_parameters.fit' (MemoryDataset)... ]8;id=237628;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=887535;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py#475\475]8;;\
# (array(['farmacia calle huertas', 'cal deu', 'restaurante chino hongkong',
#        ..., 'autoescuela ronda', 'vincci seleccion la plantacion del sur',
#        'goikogane'], dtype=object), array(['farmacia huertas', 'el molinot', 'hong kong', ...,
#        'autoescuela nueva ronda', 'vincci la plantacion', 'atxandita'],
#       dtype=object))
# Epoch 1/5
# 124/187 [==================>...........] - ETA: 17s - loss: 0.6942 - accuracy: 0.4968 - precision_1: 0.4981 - recall_1: 0.5680
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 11>:11                                                                            │
# │                                                                                                  │
# │    8 fit_parameters = catalog.load('params:model_parameters.fit')                                │
# │    9 history = History()                                                                         │
# │   10                                                                                             │
# │ ❱ 11 model.fit(                                                                                  │
# │   12 │   training_pairs=(X1_train, X2_train),                                                    │
# │   13 │   target=target_train,                                                                    │
# │   14 │   max_epochs=fit_parameters['max_epochs'],                                                │
# │                                                                                                  │
# │ /workspace/src/entity_name_matching_dnn/pipelines/train_model/model.py:130 in fit                │
# │                                                                                                  │
# │   127 │   │                                                                                      │
# │   128 │   │   _callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=pati   │
# │   129 │   │                                                                                      │
# │ ❱ 130 │   │   self.model.fit(                                                                    │
# │   131 │   │   │   (X1, X2),                                                                      │
# │   132 │   │   │   target,                                                                        │
# │   133 │   │   │   verbose=1,                                                                     │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py:65 in error_handler        │
# │                                                                                                  │
# │    62 │   │                                                                                      │
# │    63 │   │   filtered_tb = None                                                                 │
# │    64 │   │   try:                                                                               │
# │ ❱  65 │   │   │   return fn(*args, **kwargs)                                                     │
# │    66 │   │   except Exception as e:                                                             │
# │    67 │   │   │   filtered_tb = _process_traceback_frames(e.__traceback__)                       │
# │    68 │   │   │   # To get the full stack trace, call:                                           │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/keras/engine/training.py:1650 in fit                      │
# │                                                                                                  │
# │   1647 │   │   │   │   │   │   │   _r=1,                                                         │
# │   1648 │   │   │   │   │   │   ):                                                                │
# │   1649 │   │   │   │   │   │   │   callbacks.on_train_batch_begin(step)                          │
# │ ❱ 1650 │   │   │   │   │   │   │   tmp_logs = self.train_function(iterator)                      │
# │   1651 │   │   │   │   │   │   │   if data_handler.should_sync:                                  │
# │   1652 │   │   │   │   │   │   │   │   context.async_wait()                                      │
# │   1653 │   │   │   │   │   │   │   # No error, now safe to assign to logs.                       │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py:150 in          │
# │ error_handler                                                                                    │
# │                                                                                                  │
# │   147 │                                                                                          │
# │   148 │   filtered_tb = None                                                                     │
# │   149 │   try:                                                                                   │
# │ ❱ 150 │     return fn(*args, **kwargs)                                                           │
# │   151 │   except Exception as e:                                                                 │
# │   152 │     filtered_tb = _process_traceback_frames(e.__traceback__)                             │
# │   153 │     raise e.with_traceback(filtered_tb) from None                                        │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_ │
# │ function.py:880 in __call__                                                                      │
# │                                                                                                  │
# │    877 │     compiler = "xla" if self._jit_compile else "nonXla"                                 │
# │    878 │                                                                                         │
# │    879 │     with OptionalXlaContext(self._jit_compile):                                         │
# │ ❱  880 │   │   result = self._call(*args, **kwds)                                                │
# │    881 │                                                                                         │
# │    882 │     new_tracing_count = self.experimental_get_tracing_count()                           │
# │    883 │     without_tracing = (tracing_count == new_tracing_count)                              │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_ │
# │ function.py:912 in _call                                                                         │
# │                                                                                                  │
# │    909 │     self._lock.release()                                                                │
# │    910 │     # In this case we have created variables on the first call, so we run the           │
# │    911 │     # defunned version which is guaranteed to never create variables.                   │
# │ ❱  912 │     return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callabl  │
# │    913 │   elif self._variable_creation_fn is not None:                                          │
# │    914 │     # Release the lock early so that multiple threads can perform the call              │
# │    915 │     # in parallel.                                                                      │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_comp │
# │ iler.py:134 in __call__                                                                          │
# │                                                                                                  │
# │   131 │   with self._lock:                                                                       │
# │   132 │     (concrete_function,                                                                  │
# │   133 │      filtered_flat_args) = self._maybe_define_function(args, kwargs)                     │
# │ ❱ 134 │   return concrete_function._call_flat(                                                   │
# │   135 │   │   filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint   │
# │   136                                                                                            │
# │   137   @property                                                                                │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_ │
# │ function.py:1745 in _call_flat                                                                   │
# │                                                                                                  │
# │   1742 │   if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE             │
# │   1743 │   │   and executing_eagerly):                                                           │
# │   1744 │     # No tape is watching; skip to running the function.                                │
# │ ❱ 1745 │     return self._build_call_outputs(self._inference_function.call(                      │
# │   1746 │   │     ctx, args, cancellation_manager=cancellation_manager))                          │
# │   1747 │   forward_backward = self._select_forward_and_backward_functions(                       │
# │   1748 │   │   args,                                                                             │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_ │
# │ function.py:378 in call                                                                          │
# │                                                                                                  │
# │    375 │   if executing_eagerly:                                                                 │
# │    376 │     with _InterpolateFunctionError(self):                                               │
# │    377 │   │   if cancellation_manager is None:                                                  │
# │ ❱  378 │   │     outputs = execute.execute(                                                      │
# │    379 │   │   │     str(self.signature.name),                                                   │
# │    380 │   │   │     num_outputs=self._num_outputs,                                              │
# │    381 │   │   │     inputs=args,                                                                │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/execute.py:52 in quick_execute    │
# │                                                                                                  │
# │    49   # pylint: disable=protected-access                                                       │
# │    50   try:                                                                                     │
# │    51 │   ctx.ensure_initialized()                                                               │
# │ ❱  52 │   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,                 │
# │    53 │   │   │   │   │   │   │   │   │   │   inputs, attrs, num_outputs)                        │
# │    54   except core._NotOkStatusException as e:                                                  │
# │    55 │   if name is not None:                                                                   │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt

# %%
X_train = catalog.load('train')
# Out:
# [09/03/23 21:38:20] INFO     Loading data from 'train' (CSVDataSet)...                          ]8;id=828413;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=730002;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py#475\475]8;;\

# %%
X_train.loc[[1,4,2]]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    reference_id brand                        name           alt_name  \
# 1   46277096854   NaN                     Cal Déu         el Molinot
# 4   33913358616   NaN                  El Triunfo  Hostal El Triunfo
# 2   34007673148   NaN  Restaurante Chino Hongkong          Hong-Kong
#
#                                                 tags   latitude  longitude  \
# 1  "license"=>"ODbL", "osm_uid"=>"1", "alt_name"=...  42.080492   1.781784
# 4  "user"=>"tomtom", "email"=>"reservas@hostaltri...  37.878365  -4.778780
# 2  "user"=>"tomtom", "phone"=>"+34922411308", "cu...  28.687215 -17.772395
#
#                category_fields             name_normalized  \
# 1  ['place=isolated_dwelling']                     cal deu
# 4            ['tourism=hotel']                  el triunfo
# 2       ['amenity=restaurant']  restaurante chino hongkong
#
#   alt_name_normalized              run_id country  target
# 1          el molinot  20230901-test-0005     esp       0
# 4   hostal el triunfo  20230901-test-0005     esp       0
# 2           hong kong  20230901-test-0005     esp       1

# %%
indexes = X_train.index.tolist()
np.random.shuffle(indexes)

# %%
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# array(['Boutique-hotel - Posada Terra Santa', 'Restaurante El Principe',
#        'Cala de Gulpiyuri', ..., 'Jamoneria La Bellota', 'Gaztarri',
#        'La Móra'], dtype=object)

# %%
X_train
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        reference_id      brand                                    name  \
# 0       33963143455        NaN                  Farmacia Calle Huertas
# 1       46277096854        NaN                                 Cal Déu
# 2       34007673148        NaN              Restaurante Chino Hongkong
# 3       33956757671  Five Guys                               Five Guys
# 4       33913358616        NaN                              El Triunfo
# ...             ...        ...                                     ...
# 47713   33908137014        NaN                        Taberna La Campa
# 47714   33947006140   Domino's                                Domino's
# 47715   33944581636        NaN                       Autoescuela Ronda
# 47716   33997412510        NaN  Vincci Seleccion La Plantacion Del Sur
# 47717    3144046947        NaN                               Goikogane
#
#                               alt_name  \
# 0                     Farmacia Huertas
# 1                           el Molinot
# 2                            Hong-Kong
# 3      Five Guys Bilbao Plaza Circular
# 4                    Hostal El Triunfo
# ...                                ...
# 47713                         La Campa
# 47714               Domino's Velazquez
# 47715          Autoescuela Nueva Ronda
# 47716             Vincci La Plantacion
# 47717                        Atxandita
#
#                                                     tags   latitude  \
# 0      "user"=>"tomtom", "email"=>"elenaramiro@hotmai...  40.413902
# 1      "license"=>"ODbL", "osm_uid"=>"1", "alt_name"=...  42.080492
# 2      "user"=>"tomtom", "phone"=>"+34922411308", "cu...  28.687215
# 3      "user"=>"tomtom", "phone"=>"+34946662961", "li...  43.261337
# 4      "user"=>"tomtom", "email"=>"reservas@hostaltri...  37.878365
# ...                                                  ...        ...
# 47713  "user"=>"tomtom", "phone"=>"+34985608069", "cu...  43.181736
# 47714  "user"=>"tomtom", "phone"=>"+34952343104", "cu...  36.698340
# 47715  "user"=>"tomtom", "email"=>"Gestion@aeronda.co...  40.309041
# 47716  "fax"=>"+(34)-(922)-712750", "user"=>"tomtom",...  28.094286
# 47717  "license"=>"ODbL", "osm_uid"=>"1", "alt_name"=...  43.170623
#
#        longitude              category_fields  \
# 0      -3.699700         ['amenity=pharmacy']
# 1       1.781784  ['place=isolated_dwelling']
# 2     -17.772395       ['amenity=restaurant']
# 3      -2.926707        ['amenity=fast_food']
# 4      -4.778780            ['tourism=hotel']
# ...          ...                          ...
# 47713  -5.344619       ['amenity=restaurant']
# 47714  -4.447830       ['amenity=restaurant']
# 47715  -3.447413   ['amenity=driving_school']
# 47716 -16.742963            ['tourism=hotel']
# 47717  -2.947042             ['natural=peak']
#
#                               name_normalized  \
# 0                      farmacia calle huertas
# 1                                     cal deu
# 2                  restaurante chino hongkong
# 3                                   five guys
# 4                                  el triunfo
# ...                                       ...
# 47713                        taberna la campa
# 47714                                 dominos
# 47715                       autoescuela ronda
# 47716  vincci seleccion la plantacion del sur
# 47717                               goikogane
#
#                    alt_name_normalized              run_id country  target  \
# 0                     farmacia huertas  20230901-test-0005     esp       0
# 1                           el molinot  20230901-test-0005     esp       0
# 2                            hong kong  20230901-test-0005     esp       1
# 3      five guys bilbao plaza circular  20230901-test-0005     esp       0
# 4                    hostal el triunfo  20230901-test-0005     esp       0
# ...                                ...                 ...     ...     ...
# 47713                         la campa  20230901-test-0005     esp       0
# 47714                dominos velazquez  20230901-test-0005     esp       1
# 47715          autoescuela nueva ronda  20230901-test-0005     esp       0
# 47716             vincci la plantacion  20230901-test-0005     esp       1
# 47717                        atxandita  20230901-test-0005     esp       1
#
#                          new_alt_names
# 0                     Farmacia Huertas
# 1                           el Molinot
# 2                            Hong-Kong
# 3      Five Guys Bilbao Plaza Circular
# 4                    Hostal El Triunfo
# ...                                ...
# 47713                         La Campa
# 47714               Domino's Velazquez
# 47715          Autoescuela Nueva Ronda
# 47716             Vincci La Plantacion
# 47717                        Atxandita
#
# [47718 rows x 14 columns]

# %%
X_train[['alt_name', 'new_alt_names']]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                               alt_name                    new_alt_names
# 0                     Farmacia Huertas                 Farmacia Huertas
# 1                           el Molinot                       el Molinot
# 2                            Hong-Kong                        Hong-Kong
# 3      Five Guys Bilbao Plaza Circular  Five Guys Bilbao Plaza Circular
# 4                    Hostal El Triunfo                Hostal El Triunfo
# ...                                ...                              ...
# 47713                         La Campa                         La Campa
# 47714               Domino's Velazquez               Domino's Velazquez
# 47715          Autoescuela Nueva Ronda          Autoescuela Nueva Ronda
# 47716             Vincci La Plantacion             Vincci La Plantacion
# 47717                        Atxandita                        Atxandita
#
# [47718 rows x 2 columns]

# %%
import pyspark
def generate_training_examples(df: pyspark.sql.DataFrame
                               ) -> pyspark.sql.DataFrame:
    
    #TODO: Implement more sophisticated negative examples

    positive_examples = df.toPandas()
    positive_examples['target'] = 1

    negative_examples = positive_examples.copy()
    negative_examples['target'] = 0

    np.random.seed(1)
    indexes = positive_examples.index.tolist()
    np.random.shuffle(indexes)

    negative_examples['alt_name'] = positive_examples.loc[indexes, 'alt_name']
    negative_examples['alt_name_normalized'] = positive_examples.loc[indexes, 'alt_name_normalized']

    training_data = pd.concat([positive_examples, negative_examples], axis=0)

    return training_data

# %%
normalized_pairs = catalog.load('df_normalized_pairs')
# Out:
# [09/03/23 22:07:09] INFO     Loading data from 'df_normalized_pairs' (SparkDataSet)...          ]8;id=832650;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=289496;file:///usr/local/lib/python3.9/dist-packages/kedro/io/data_catalog.py#475\475]8;;\

# %%
normalized_pairs.count()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 29824

# %%
import numpy as np
import pandas as pd

# %%
train = generate_training_examples(normalized_pairs)

# %%
train
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       reference_id     brand  \
# 0      47905637612      None
# 1      33939964186      None
# 2      33920295151      None
# 3       9151154135      None
# 4      34029676494  Domino's
# ...            ...       ...
# 29819  33933382525      None
# 29820  33950966775      None
# 29821  34005477933      None
# 29822   2904773690      None
# 29823  33937469763      None
#
#                                                     name  \
# 0                                            Olabarrieta
# 1                                             Hotel Selu
# 2      Centro Privado de Educación Infantil Jugar Y S...
# 3                                          Mi Peluquería
# 4                                               Domino's
# ...                                                  ...
# 29819                                             Llesca
# 29820  Centro Privado Autorizado de Enseñanzas Deport...
# 29821                        Restaurante Rincon De Pedro
# 29822                                    Font de l'Aueta
# 29823                                        Led Serveis
#
#                                       alt_name  \
# 0                                Las Barrietas
# 1                   Sercotel Hotels Selu Hotel
# 2                               Jugar Y Sentir
# 3                       Peluquería Nuria Bailo
# 4                              Domino's Tellez
# ...                                        ...
# 29819                   Gastrotaberna Illescas
# 29820  Ufedema-Centro de Enseñanzas deportivas
# 29821                          Rincon De Pedro
# 29822                         la Font de Cossi
# 29823                     Led Serveis Banyoles
#
#                                                     tags   latitude  \
# 0      "license"=>"ODbL", "osm_uid"=>"1", "alt_name"=...  43.273544
# 1      "fax"=>"+(34)-(957)-478376", "user"=>"tomtom",...  37.884247
# 2      "user"=>"tomtom", "phone"=>"+34600257838", "li...  40.588801
# 3      "phone"=>"+34 942 31 25 75", "license"=>"ODbL"...  43.469193
# 4      "user"=>"tomtom", "phone"=>"+34910900924", "cu...  40.402120
# ...                                                  ...        ...
# 29819  "user"=>"tomtom", "phone"=>"+34925541064", "cu...  40.121636
# 29820  "user"=>"tomtom", "phone"=>"+34912115601", "sc...  40.373642
# 29821  "user"=>"tomtom", "email"=>"rincondepedro@live...  38.077685
# 29822  "license"=>"ODbL", "osm_uid"=>"1", "alt_name"=...  38.736821
# 29823  "user"=>"tomtom", "craft"=>"electronics_repair...  42.115739
#
#        longitude             category_fields  \
# 0      -3.045194            [place=locality]
# 1      -4.783952             [tourism=hotel]
# 2      -3.708725      [amenity=kindergarten]
# 3      -3.808571          [shop=hairdresser]
# 4      -3.678620        [amenity=restaurant]
# ...          ...                         ...
# 29819  -3.849563        [amenity=restaurant]
# 29820  -3.920745            [amenity=school]
# 29821  -0.649647        [amenity=restaurant]
# 29822  -0.353900            [natural=spring]
# 29823   2.762596  [craft=electronics_repair]
#
#                                          name_normalized  \
# 0                                            olabarrieta
# 1                                             hotel selu
# 2      centro privado de educacion infantil jugar y s...
# 3                                          mi peluqueria
# 4                                                dominos
# ...                                                  ...
# 29819                                             llesca
# 29820  centro privado autorizado de ensenanzas deport...
# 29821                        restaurante rincon de pedro
# 29822                                     font de laueta
# 29823                                        led serveis
#
#                            alt_name_normalized              run_id country  \
# 0                                las barrietas  20230901-test-0006     esp
# 1                   sercotel hotels selu hotel  20230901-test-0006     esp
# 2                               jugar y sentir  20230901-test-0006     esp
# 3                       peluqueria nuria bailo  20230901-test-0006     esp
# 4                               dominos tellez  20230901-test-0006     esp
# ...                                        ...                 ...     ...
# 29819                   gastrotaberna illescas  20230901-test-0006     esp
# 29820  ufedema centro de ensenanzas deportivas  20230901-test-0006     esp
# 29821                          rincon de pedro  20230901-test-0006     esp
# 29822                         la font de cossi  20230901-test-0006     esp
# 29823                     led serveis banyoles  20230901-test-0006     esp
#
#        target
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 29819       0
# 29820       0
# 29821       0
# 29822       0
# 29823       0
#
# [59648 rows x 13 columns]
